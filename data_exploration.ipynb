# %%
wiki_id = []
for i in range(1, 110):
    str = "wiki-{:03d}.txt".format(i)
    wiki_id.append(str)
print(wiki_id)
for el in wiki_id:
    with open("/Users/neesergparajuli/Dropbox/Web text/Data/wiki-pages-text/"+el) as f:
        for j, l in enumerate(f):
            pass
        print(j+1)
# Out:
# ['wiki-001.txt', 'wiki-002.txt', 'wiki-003.txt', 'wiki-004.txt', 'wiki-005.txt', 'wiki-006.txt', 'wiki-007.txt', 'wiki-008.txt', 'wiki-009.txt', 'wiki-010.txt', 'wiki-011.txt', 'wiki-012.txt', 'wiki-013.txt', 'wiki-014.txt', 'wiki-015.txt', 'wiki-016.txt', 'wiki-017.txt', 'wiki-018.txt', 'wiki-019.txt', 'wiki-020.txt', 'wiki-021.txt', 'wiki-022.txt', 'wiki-023.txt', 'wiki-024.txt', 'wiki-025.txt', 'wiki-026.txt', 'wiki-027.txt', 'wiki-028.txt', 'wiki-029.txt', 'wiki-030.txt', 'wiki-031.txt', 'wiki-032.txt', 'wiki-033.txt', 'wiki-034.txt', 'wiki-035.txt', 'wiki-036.txt', 'wiki-037.txt', 'wiki-038.txt', 'wiki-039.txt', 'wiki-040.txt', 'wiki-041.txt', 'wiki-042.txt', 'wiki-043.txt', 'wiki-044.txt', 'wiki-045.txt', 'wiki-046.txt', 'wiki-047.txt', 'wiki-048.txt', 'wiki-049.txt', 'wiki-050.txt', 'wiki-051.txt', 'wiki-052.txt', 'wiki-053.txt', 'wiki-054.txt', 'wiki-055.txt', 'wiki-056.txt', 'wiki-057.txt', 'wiki-058.txt', 'wiki-059.txt', 'wiki-060.txt', 'wiki-061.txt', 'wiki-062.txt', 'wiki
# ...

# %%
with open('/Users/neesergparajuli/Dropbox/Webtext/Data/wiki-pages-text/wiki-001.txt') as f:
    i =0
    for line in f:
        i+=1
        print(line)
        if i>1000:
            break
# Out:
# 1928_in_association_football 0 The following are the football -LRB- soccer -RRB- events of the year 1928 throughout the world .
#
# 1986_NBA_Finals 0 The 1986 NBA Finals was the championship round of the 1985 -- 86 NBA season .
#
# 1986_NBA_Finals 1 It pitted the Eastern Conference champion Boston Celtics against the Western Conference champion Houston Rockets , in a rematch of the 1981 Finals -LRB- only Allen Leavell and Robert Reid remained from the Rockets ' 1981 team -RRB- .
#
# 1986_NBA_Finals 2 The Celtics defeated the Rockets four games to two to win their 16th NBA championship .
#
# 1986_NBA_Finals 3 The championship would be the Celtics ' last until the 2008 NBA Finals .
#
# 1986_NBA_Finals 4 Larry Bird was named the Finals MVP .
#
# ...
